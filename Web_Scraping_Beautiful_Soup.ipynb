# %% [markdown]
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://en.wikipedia.org/wiki/Main_Page')

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
url = requests.get('https://en.wikipedia.org/wiki/Main_Page')
soup = BeautifulSoup(url.text, 'html.parser')
header_tags = soup.find_all(['h1', 'h2','h3'])
for i in header_tags:
    print(i)
# Out:
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none">Main Page</h1>
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
# <h2 class="mp-h2" id="mp-tfl-h2"><span id="From_today.27s_featured_list"></span><span class="mw-headline" id="From_today's_featured_list">From today's featured list</span></h2>
# ...

# %% [markdown]
# Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release)
# and make data frame

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://www.imdb.com/chart/top/?ref_=nv_mv_250')

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    Top 250 Movies - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
#   </script>
# ...

# %%
titles = []

for i in soup.find_all('td',class_="titleColumn"):
    titles.append(i.text)
print(titles)
# Out:
# ['\n      1.\n      The Shawshank Redemption\n(1994)\n', '\n      2.\n      The Godfather\n(1972)\n', '\n      3.\n      The Dark Knight\n(2008)\n', '\n      4.\n      The Godfather: Part II\n(1974)\n', '\n      5.\n      12 Angry Men\n(1957)\n', "\n      6.\n      Schindler's List\n(1993)\n", '\n      7.\n      The Lord of the Rings: The Return of the King\n(2003)\n', '\n      8.\n      Pulp Fiction\n(1994)\n', '\n      9.\n      The Lord of the Rings: The Fellowship of the Ring\n(2001)\n', '\n      10.\n      Il buono, il brutto, il cattivo\n(1966)\n', '\n      11.\n      Forrest Gump\n(1994)\n', '\n      12.\n      Fight Club\n(1999)\n', '\n      13.\n      Inception\n(2010)\n', '\n      14.\n      The Lord of the Rings: The Two Towers\n(2002)\n', '\n      15.\n      The Empire Strikes Back\n(1980)\n', '\n      16.\n      The Matrix\n(1999)\n', '\n      17.\n      Goodfellas\n(1990)\n', "\n      18.\n      One Flew Over the Cuckoo's Nest\n(1975)\n", '\n      19.\n      Se7en\n(199
# ...

# %%
Ratings = []
for i in soup.find_all('td',class_="ratingColumn imdbRating"):
    Ratings.append(i.text)
print(Ratings)
# Out:
# ['\n9.2\n', '\n9.2\n', '\n9.0\n', '\n9.0\n', '\n8.9\n', '\n8.9\n', '\n8.9\n', '\n8.9\n', '\n8.8\n', '\n8.8\n', '\n8.8\n', '\n8.8\n', '\n8.7\n', '\n8.7\n', '\n8.7\n', '\n8.7\n', '\n8.7\n', '\n8.6\n', '\n8.6\n', '\n8.6\n', '\n8.6\n', '\n8.6\n', '\n8.6\n', '\n8.6\n', '\n8.6\n', '\n8.6\n', '\n8.6\n', '\n8.6\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.5\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.4\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\n', '\n8.3\
# ...

# %%
years = []
for i in soup.find_all('span',class_="secondaryInfo"):
    years.append(i.text)
    print(years)
# Out:
# ['(1994)']
# ['(1994)', '(1972)']
# ['(1994)', '(1972)', '(2008)']
# ['(1994)', '(1972)', '(2008)', '(1974)']
# ['(1994)', '(1972)', '(2008)', '(1974)', '(1957)']
# ['(1994)', '(1972)', '(2008)', '(1974)', '(1957)', '(1993)']
# ['(1994)', '(1972)', '(2008)', '(1974)', '(1957)', '(1993)', '(2003)']
# ['(1994)', '(1972)', '(2008)', '(1974)', '(1957)', '(1993)', '(2003)', '(1994)']
# ['(1994)', '(1972)', '(2008)', '(1974)', '(1957)', '(1993)', '(2003)', '(1994)', '(2001)']
# ['(1994)', '(1972)', '(2008)', '(1974)', '(1957)', '(1993)', '(2003)', '(1994)', '(2001)', '(1966)']
# ['(1994)', '(1972)', '(2008)', '(1974)', '(1957)', '(1993)', '(2003)', '(1994)', '(2001)', '(1966)', '(1994)']
# ['(1994)', '(1972)', '(2008)', '(1974)', '(1957)', '(1993)', '(2003)', '(1994)', '(2001)', '(1966)', '(1994)', '(1999)']
# ['(1994)', '(1972)', '(2008)', '(1974)', '(1957)', '(1993)', '(2003)', '(1994)', '(2001)', '(1966)', '(1994)', '(1999)', '(2010)']
# ...

# %%
import pandas as pd
df=pd.DataFrame({'titles':titles,'Ratings':Ratings,'years':years})
df
# Out:
#                                                 titles  Ratings   years
# 0    \n      1.\n      The Shawshank Redemption\n(1...  \n9.2\n  (1994)
# 1            \n      2.\n      The Godfather\n(1972)\n  \n9.2\n  (1972)
# 2          \n      3.\n      The Dark Knight\n(2008)\n  \n9.0\n  (2008)
# 3    \n      4.\n      The Godfather: Part II\n(197...  \n9.0\n  (1974)
# 4             \n      5.\n      12 Angry Men\n(1957)\n  \n8.9\n  (1957)
# ..                                                 ...      ...     ...
# 245              \n      246.\n      Aladdin\n(1992)\n  \n8.0\n  (1992)
# 246             \n      247.\n      The Help\n(2011)\n  \n8.0\n  (2011)
# 247  \n      248.\n      Beauty and the Beast\n(199...  \n8.0\n  (1991)
# 248  \n      249.\n      Du rififi chez les hommes\...  \n8.0\n  (1955)
# 249   \n      250.\n      Dances with Wolves\n(1990)\n  \n8.0\n  (1990)
#
# [250 rows x 3 columns]

# %%
# !pip install bs4

# %%
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://meesho.com/bags-ladies/pl/p7vbp')

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
names=[]
for i in soup.find_all(class_="Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS"):
    names.append(i.text)

names
# Out:
# ['Ravishing Alluring Women Handbags',
#  'Graceful Fancy Women Handbags',
#  'Ravishing Classy Women Handbags',
#  'Classic Versatile Women Handbags',
#  'Voguish Fancy Women Handbags',
#  'Graceful Versatile Women Handbags',
#  'Classic Stylish Women Handbags',
#  'Ravishing Fashionable Women Handbags',
#  'Elegant Classy Women Handbags',
#  'Elegant Alluring Women Handbags',
#  'Classic Alluring Women Handbags',
#  'Elegant Fashionable Women Handbags',
#  'Trendy Alluring Women Handbags',
#  'Trendy Alluring Women Handbags',
#  'Classic Fancy Women Handbags',
#  'Classic Fashionable Women Handbags']

# %%
prices=[]
for i in soup.find_all(class_="Text__StyledText-sc-oo0kvp-0 hiHdyy"):
    prices.append(i.text)

prices
# Out:
# ['₹384',
#  '₹528',
#  '₹950',
#  '₹950',
#  '₹1549',
#  '₹950',
#  '₹3202',
#  '₹316',
#  '₹950',
#  '₹2337',
#  '₹518',
#  '₹725',
#  '₹1320',
#  '₹950',
#  '₹646',
#  '₹620']

# %%
discounts=[]
for i in soup.find_all(class_="Text__StyledText-sc-oo0kvp-0 lnonyH"):
    discounts.append(i.text)

discounts
# Out:
# ['12% off',
#  '9% off',
#  '5% off',
#  '5% off',
#  '3% off',
#  '5% off',
#  '2% off',
#  '14% off',
#  '5% off',
#  '2% off',
#  '9% off',
#  '6% off',
#  '4% off',
#  '5% off',
#  '7% off',
#  '7% off']

# %%
import pandas as pd

# %%
df2=pd.DataFrame({'Bag_Name':names,'Price':prices,'Offer':discounts})
df2
# Out:
#                                 Bag_Name  Price    Offer
# 0      Ravishing Alluring Women Handbags   ₹384  12% off
# 1          Graceful Fancy Women Handbags   ₹528   9% off
# 2        Ravishing Classy Women Handbags   ₹950   5% off
# 3       Classic Versatile Women Handbags   ₹950   5% off
# 4           Voguish Fancy Women Handbags  ₹1549   3% off
# 5      Graceful Versatile Women Handbags   ₹950   5% off
# 6         Classic Stylish Women Handbags  ₹3202   2% off
# 7   Ravishing Fashionable Women Handbags   ₹316  14% off
# 8          Elegant Classy Women Handbags   ₹950   5% off
# 9        Elegant Alluring Women Handbags  ₹2337   2% off
# 10       Classic Alluring Women Handbags   ₹518   9% off
# 11    Elegant Fashionable Women Handbags   ₹725   6% off
# 12        Trendy Alluring Women Handbags  ₹1320   4% off
# 13        Trendy Alluring Women Handbags   ₹950   5% off
# 14          Classic Fancy Women Handbags   ₹646   7% off
# ...

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
matches=[]

for i in soup.find_all(class_="table-body__cell rankings-table__team"):
    matches.append(i.text)
    
matches
# Out:
# ['\n\nEngland\nENG\n',
#  '\n\nAustralia\nAUS\n',
#  '\n\nIndia\nIND\n',
#  '\n\nSouth Africa\nSA\n',
#  '\n\nPakistan\nPAK\n',
#  '\n\nBangladesh\nBAN\n',
#  '\n\nSri Lanka\nSL\n',
#  '\n\nWest Indies\nWI\n',
#  '\n\nAfghanistan\nAFG\n',
#  '\n\nIreland\nIRE\n',
#  '\n\nScotland\nSCO\n',
#  '\n\nZimbabwe\nZIM\n',
#  '\n\nNetherlands\nNED\n',
#  '\n\nUAE\nUAE\n',
#  '\n\nOman\nOMA\n',
#  '\n\nNamibia\nNAM\n',
#  '\n\nNepal\nNEP\n',
#  '\n\nUnited States\nUSA\n',
#  '\n\nPapua New Guinea\nPNG\n']

# %%
Ratings=[]

for i in soup.find_all(class_="table-body__cell u-text-right rating"):
    Ratings.append(i.text)
    
Ratings
# Out:
# ['119',
#  '112',
#  '110',
#  '102',
#  '97',
#  '93',
#  '81',
#  '77',
#  '68',
#  '52',
#  '51',
#  '41',
#  '35',
#  '33',
#  '29',
#  '21',
#  '18',
#  '17',
#  '8']

# %%
import pandas as pd
df=pd.DataFrame({'Team':matches,'Rating':Ratings})
df
# Out:
#                            Team Rating
# 0            \n\nEngland\nENG\n    119
# 1          \n\nAustralia\nAUS\n    112
# 2              \n\nIndia\nIND\n    110
# 3        \n\nSouth Africa\nSA\n    102
# 4           \n\nPakistan\nPAK\n     97
# 5         \n\nBangladesh\nBAN\n     93
# 6           \n\nSri Lanka\nSL\n     81
# 7         \n\nWest Indies\nWI\n     77
# 8        \n\nAfghanistan\nAFG\n     68
# 9            \n\nIreland\nIRE\n     52
# 10          \n\nScotland\nSCO\n     51
# 11          \n\nZimbabwe\nZIM\n     41
# 12       \n\nNetherlands\nNED\n     35
# 13               \n\nUAE\nUAE\n     33
# 14              \n\nOman\nOMA\n     29
# 15           \n\nNamibia\nNAM\n     21
# 16             \n\nNepal\nNEP\n     18
# 17     \n\nUnited States\nUSA\n     17
# 18  \n\nPapua New Guinea\nPNG\n      8

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %%
name=[]

for i in soup.find_all(class_="table-body__cell name"):
    name.append(i.text)
    
name
# Out:
# ['\nVirat Kohli\n',
#  '\nImam-ul-Haq\n',
#  '\nRohit Sharma\n',
#  '\nQuinton de Kock\n',
#  '\nJonny Bairstow\n',
#  '\nRoss Taylor\n',
#  '\nRassie van der Dussen\n',
#  '\nDavid Warner\n',
#  '\nAaron Finch\n',
#  '\nChris Woakes\n',
#  '\nJosh Hazlewood\n',
#  '\nMatt Henry\n',
#  '\nMujeeb Ur Rahman\n',
#  '\nJasprit Bumrah\n',
#  '\nShaheen Afridi\n',
#  '\nMehedi Hasan\n',
#  '\nShakib Al Hasan\n',
#  '\nRashid Khan\n',
#  '\nMohammad Nabi\n',
#  '\nChris Woakes\n',
#  '\nRashid Khan\n',
#  '\nBen Stokes\n',
#  '\nColin de Grandhomme\n',
#  '\nMitchell Santner\n',
#  '\nImad Wasim\n',
#  '\nMehedi Hasan\n',
#  '\nRavindra Jadeja\n',
#  '\nVirat Kohli\n',
#  '\nImam-ul-Haq\n',
#  '\nRohit Sharma\n',
#  '\nQuinton de Kock\n',
#  '\nJonny Bairstow\n',
#  '\nRoss Taylor\n',
#  '\nRassie van der Dussen\n',
#  '\nDavid Warner\n',
#  '\nAaron Finch\n',
#  '\nChris Woakes\n',
#  '\nJosh Hazlewood\n',
#  '\nMatt Henry\n',
#  '\nMujeeb Ur Rahman\n',
#  '\nJasprit Bumrah\n',
# ...

# %%
team=[]

for i in soup.find_all(class_="table-body__logo-text"):
    team.append(i.text)
    
team
# Out:
# ['IND',
#  'PAK',
#  'IND',
#  'SA',
#  'ENG',
#  'NZ',
#  'SA',
#  'AUS',
#  'AUS',
#  'ENG',
#  'AUS',
#  'NZ',
#  'AFG',
#  'IND',
#  'PAK',
#  'BAN',
#  'BAN',
#  'AFG',
#  'AFG',
#  'ENG',
#  'AFG',
#  'ENG',
#  'NZ',
#  'NZ',
#  'PAK',
#  'BAN',
#  'IND',
#  'IND',
#  'PAK',
#  'IND',
#  'SA',
#  'ENG',
#  'NZ',
#  'SA',
#  'AUS',
#  'AUS',
#  'ENG',
#  'AUS',
#  'NZ',
#  'AFG',
#  'IND',
#  'PAK',
#  'BAN',
#  'BAN',
#  'AFG',
#  'AFG',
#  'ENG',
#  'AFG',
#  'ENG',
#  'NZ',
#  'NZ',
#  'PAK',
#  'BAN',
#  'IND']

# %%
ranking=[]

for i in soup.find_all(class_="table-body__cell u-text-right rating"):
    ranking.append(i.text)
    
ranking
# Out:
# ['811',
#  '795',
#  '791',
#  '789',
#  '775',
#  '775',
#  '769',
#  '750',
#  '745',
#  '700',
#  '698',
#  '683',
#  '681',
#  '679',
#  '671',
#  '661',
#  '657',
#  '650',
#  '295',
#  '282',
#  '276',
#  '266',
#  '262',
#  '260',
#  '248',
#  '233',
#  '224',
#  '811',
#  '795',
#  '791',
#  '789',
#  '775',
#  '775',
#  '769',
#  '750',
#  '745',
#  '700',
#  '698',
#  '683',
#  '681',
#  '679',
#  '671',
#  '661',
#  '657',
#  '650',
#  '295',
#  '282',
#  '276',
#  '266',
#  '262',
#  '260',
#  '248',
#  '233',
#  '224']

# %%
import pandas as pd
df=pd.DataFrame({'Name':name,'Team':team,'Rating':ranking})
df
# Out:
#                          Name Team Rating
# 0             \nVirat Kohli\n  IND    811
# 1             \nImam-ul-Haq\n  PAK    795
# 2            \nRohit Sharma\n  IND    791
# 3         \nQuinton de Kock\n   SA    789
# 4          \nJonny Bairstow\n  ENG    775
# 5             \nRoss Taylor\n   NZ    775
# 6   \nRassie van der Dussen\n   SA    769
# 7            \nDavid Warner\n  AUS    750
# 8             \nAaron Finch\n  AUS    745
# 9            \nChris Woakes\n  ENG    700
# 10         \nJosh Hazlewood\n  AUS    698
# 11             \nMatt Henry\n   NZ    683
# 12       \nMujeeb Ur Rahman\n  AFG    681
# 13         \nJasprit Bumrah\n  IND    679
# 14         \nShaheen Afridi\n  PAK    671
# 15           \nMehedi Hasan\n  BAN    661
# 16        \nShakib Al Hasan\n  BAN    657
# 17            \nRashid Khan\n  AFG    650
# 18          \nMohammad Nabi\n  AFG    295
# 19           \nChris Woakes\n  ENG    282
# 20            \nRashid Khan\n  AFG    276
# ...

# %%
name1=[]

for i in soup.find_all():
    name1.append(i.text)
    
name1
# Out:
#   File "C:\Users\DRC44C~1.SAI\AppData\Local\Temp/ipykernel_11800/2823676407.py", line 3
#     for i in soup.find_all(<a href="/rankings/mens/player-rankings/967">Chris Woakes</a>):
#                            ^
# SyntaxError: invalid syntax

# %%
page=requests.get('https://coreyms.com/')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This site is optimized with the Yoast SEO plugin v15.4 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>CoreyMS - Development, Design, DIY, and more</title>
# <meta content="Development, Design, DIY, and more" name="description"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="https://coreyms.com/" rel="canonical"/>
# <link href="https://coreyms.com/page/2" rel="next"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="CoreyMS - Development, Design, DIY, and more" property="og:title"/>
# <meta content="Development, Design, DIY, and more" property="og:description"/>
# <meta content="https://coreyms.com/" property="og:url"/>
# <meta content="CoreyMS" property="og:site_name"/>
# ...

# %%
heading=[]

for i in soup.find_all(class_="entry-title-link"):
    heading.append(i.text)
    
heading
# Out:
# ['Python Tutorial: Zip Files – Creating and Extracting Zip Archives',
#  'Python Data Science Tutorial: Analyzing the 2019 Stack Overflow Developer Survey',
#  'Python Multiprocessing Tutorial: Run Code in Parallel Using the Multiprocessing Module',
#  'Python Threading Tutorial: Run Code Concurrently Using the Threading Module',
#  'Update (2019-09-03)',
#  'Python Quick Tip: The Difference Between “==” and “is” (Equality vs Identity)',
#  'Python Tutorial: Calling External Commands Using the Subprocess Module',
#  'Visual Studio Code (Windows) – Setting up a Python Development Environment and Complete Overview',
#  'Visual Studio Code (Mac) – Setting up a Python Development Environment and Complete Overview',
#  'Clarifying the Issues with Mutable Default Arguments']

# %%
date=[]

for i in soup.find_all(class_="entry-time"):
    date.append(i.text)
    
date
# Out:
# ['November 19, 2019',
#  'October 17, 2019',
#  'September 21, 2019',
#  'September 12, 2019',
#  'September 3, 2019',
#  'August 6, 2019',
#  'July 24, 2019',
#  'May 1, 2019',
#  'May 1, 2019',
#  'April 24, 2019']

# %%
content=[]

for i in soup.find_all(class_="entry-content"):
    content.append(i.text)
    
content
# Out:
# ['\nIn this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…\n\n',
#  '\nIn this Python Programming video, we will be learning how to download and analyze real-world data from the 2019 Stack Overflow Developer Survey. This is terrific practice for anyone getting into the data science field. We will learn different ways to analyze this data and also some best practices. Let’s get started…\n\n\n\n',
#  '\nIn this Python Programming video, we will be learning how to run code in parallel using the multiprocessing module. We will also look at how to process multiple high-resolution images at the same time using a ProcessPoolExecutor from the concurrent.futures module. Let’s get started…\n\n\n\n',
# ...

# %%
import pandas as pd
df1=pd.DataFrame({'Heading':heading,'Date':date,'Content':content})
df1
# Out:
#                                              Heading                Date  \
# 0  Python Tutorial: Zip Files – Creating and Extr...   November 19, 2019
# 1  Python Data Science Tutorial: Analyzing the 20...    October 17, 2019
# 2  Python Multiprocessing Tutorial: Run Code in P...  September 21, 2019
# 3  Python Threading Tutorial: Run Code Concurrent...  September 12, 2019
# 4                                Update (2019-09-03)   September 3, 2019
# 5  Python Quick Tip: The Difference Between “==” ...      August 6, 2019
# 6  Python Tutorial: Calling External Commands Usi...       July 24, 2019
# 7  Visual Studio Code (Windows) – Setting up a Py...         May 1, 2019
# 8  Visual Studio Code (Mac) – Setting up a Python...         May 1, 2019
# 9  Clarifying the Issues with Mutable Default Arg...      April 24, 2019
#
#                                              Content
# 0  \nIn this video, we will be learning how to cr...
# 1  \nIn this Python Programming video, we will be...
# ...

# %%
page=requests.get('https://www.nobroker.in/property/rent/bangalore/Indiranagar?searchParam=W3sibGF0IjoxMi45NzgzNjkyLCJsb24iOjc3LjY0MDgzNTYsInBsYWNlSWQiOiJDaElKa1FOM0dLUVdyanNSTmhCUUpyaEdEN1UiLCJwbGFjZU5hbWUiOiJJbmRpcmFuYWdhciJ9XQ==&radius=2.0&sharedAccomodation=0&city=bangalore&locality=Indiranagar')

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="https://assets.adobedtm.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <!--<meta charset="utf-8"/>-->
# <meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
title=[]

for i in soup.find_all(class_="heading-6 flex items-center font-semi-bold m-0"):
    title.append(i.text)
    
title
# Out:
# ['2 BHK Flat  For Rent  In Indiranagar',
#  '2 BHK Flat  For Rent  In Standalone Building  In Indiranagar',
#  '3 BHK In Independent House  For Rent  In Indira Nagar',
#  '2 BHK Flat  For Rent  In Standalone Building  In Ulsoor',
#  '4+ BHK In Independent House  For Rent  In Indira Nagar',
#  '1 BHK Flat  For Rent  In Indiranagar',
#  '3 BHK In Independent House  For Rent  In 17th D Cross Road',
#  '1 RK In Independent House  For Rent  In Halasuru',
#  '1 BHK In Independent House  For Lease  In Doopanahalli, Indiranagar',
#  '3 BHK Flat  For Rent  In Sarada Residency ,dupanahally In 13th B Main Road, Indiranagar',
#  '2 BHK Flat  For Rent  In Sb In Indiranagar',
#  '2 BHK In Independent House  For Rent  In Sb In Indira Nagar',
#  '3 BHK In Independent House  For Rent  In Indiranagar',
#  '1 BHK Flat  For Rent  In Krishna Nilaya In Halasuru',
#  '1 BHK For Rent  In Pankaja Nilaya In Indira Nagar',
#  '3 BHK Apartment  For Rent  In Golden Daffodils In 13th Main Road',
# ...

# %%
loc=[]

for i in soup.find_all(class_="mt-0.5p overflow-hidden overflow-ellipsis whitespace-nowrap max-w-70 text-gray-light leading-4 po:mb-0 po:max-w-95"):
    loc.append(i.text)
    
loc
# Out:
# ['Standalone Building, Swamy Vivekananda Rd, Near BDA complex, Binnamangala, Stage 1,',
#  'No 114/5, OM Road, Near-Big Bazar, Old Madras Road, Bengaluru, Karnataka 560042, India',
#  'Independent House, Near to Infinitea, ESI Hospital Road HAL 2nd Stage, 100 feet road, Indiranagar, Doopanahalli, Indiranagar, Bengaluru, Karnataka 560008, India',
#  'Near B P Bakery, 20th cross Lakshmipuram,',
#  'Independent House, Indiranagar Metro Station, Chinmaya Mission Hospital Road, Stage 2, Stage 1, Indiranagar, Bengaluru, Karnataka, India',
#  'Standalone Building, Defence Colony, Near Chinmaya Mission Hospital, Andhra Bank',
#  'Independent House, glenands pet store, CMH road',
#  'Independent House, 8th cross, lakshmipram',
#  '13b main near rama temple',
#  'near to IDC kitchen',
#  'Appareddipalya,Near PlanB',
#  'Kodihalli, 80 Feet Rd, Near Bharat Sanchar Nigam Limited Customer Service Centre',
#  'Independent House, HAL 2nd Stage,  near to New Horizon Public School',
# ...

# %%
area=[]

for i in soup.find_all(class_="flex flex-col w-33pe items-center border-r border-r-solid border-card-overview-border-color tp:w-half po:w-full last:border-r-1"):
    area.append(i.text)
    
area
# Out:
# ['1,200 sqftBuiltup',
#  '₹1,00,000Deposit',
#  '900 sqftBuiltup',
#  '₹84,000Deposit',
#  '1,525 sqftBuiltup',
#  '₹2,50,000Deposit',
#  '630 sqftBuiltup',
#  '₹70,000Deposit',
#  '5,200 sqftBuiltup',
#  '₹10,00,000Deposit',
#  '450 sqftBuiltup',
#  '₹60,000Deposit',
#  '1,300 sqftBuiltup',
#  '₹2,00,000Deposit',
#  '450 sqftBuiltup',
#  '₹50,000Deposit',
#  '300 sqftBuiltup',
#  '₹6,00,000Deposit',
#  '1,450 sqftBuiltup',
#  '₹1,20,000Deposit',
#  '800 sqftBuiltup',
#  '₹3,00,000Deposit',
#  '680 sqftBuiltup',
#  '₹50,000Deposit',
#  '1,600 sqftBuiltup',
#  '₹3,00,000Deposit',
#  '500 sqftBuiltup',
#  '₹40,000Deposit',
#  '600 sqftBuiltup',
#  '₹40,000Deposit',
#  '1,750 sqftBuiltup',
#  '₹2,50,000Deposit',
#  '1,100 sqftBuiltup',
#  '₹1,00,000Deposit',
#  '650 sqftBuiltup',
#  '₹1,00,000Deposit',
#  '100 sqftBuiltup',
#  '₹30,000Deposit',
#  '500 sqftBuiltup',
#  '₹6,00,000Deposit',
#  '600 sqftBuiltup',
#  '₹1,50,000Deposit',
#  '900 sqftBuiltup',
#  '₹90,000Deposit',
# ...

# %%
import pandas as pd
df2=pd.DataFrame({'Title':title,'Location':loc,'Area':area})
df2
# Out:
#                                                 Title  \
# 0                2 BHK Flat  For Rent  In Indiranagar
# 1   2 BHK Flat  For Rent  In Standalone Building  ...
# 2   3 BHK In Independent House  For Rent  In Indir...
# 3   2 BHK Flat  For Rent  In Standalone Building  ...
# 4   4+ BHK In Independent House  For Rent  In Indi...
# 5                1 BHK Flat  For Rent  In Indiranagar
# 6   3 BHK In Independent House  For Rent  In 17th ...
# 7    1 RK In Independent House  For Rent  In Halasuru
# 8   1 BHK In Independent House  For Lease  In Doop...
# 9   3 BHK Flat  For Rent  In Sarada Residency ,dup...
# 10         2 BHK Flat  For Rent  In Sb In Indiranagar
# 11  2 BHK In Independent House  For Rent  In Sb In...
# 12  3 BHK In Independent House  For Rent  In Indir...
# 13  1 BHK Flat  For Rent  In Krishna Nilaya In Hal...
# 14  1 BHK For Rent  In Pankaja Nilaya In Indira Nagar
# 15  3 BHK Apartment  For Rent  In Golden Daffodils...
# ...

# %%
page=requests.get('https://www.bewakoof.com/women-clothing')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <link href="https://images.bewakoof.com" hreflang="en-in" rel="preconnect"/>
# <link href="https://images.bewakoof.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://static.bewakoof.com" hreflang="en-in" rel="preconnect"/>
# <link href="https://static.bewakoof.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://cdn.polyfill.io" hreflang="en-in" rel="preconnect"/>
# <link href="https://cdn.polyfill.io" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https//www.googletagmanager.com" hreflang="en-in" rel="preconnect"/>
# <link href="https//www.googletagmanager.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://fonts.gstatic.com" hreflang="en-in" rel="preconnect"/>
# <link href="https://fonts.gstatic.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://connect.facebook.net" hreflang="en-in" rel="dns-prefetch"/>
# ...

# %%
product=[]

for i in soup.find_all(class_="productCardDetail"):
    product.append(i.text)
    
product
# Out:
# ['Mid Waist Striped Hipster Panty In White   Cotton₹ 224499FEW LEFT₹199For TriBe Members ',
#  'High Waist Hipster Panty With Text Print Waistband In Blue   Cotton₹ 224499FEW LEFT₹199For TriBe Members ',
#  'Cotton High Waist Striped Hipster Panty₹ 189499FEW LEFT₹169For TriBe Members ',
#  'Mid Waist Hipster Panty With Dog Print Back In Navy   Cotton₹ 224499FEW LEFT₹199For TriBe Members ',
#  'Mid Waist Hipster Panty With Text & Graphic Print Back In Brown   Cotton₹ 224499FEW LEFT₹199For TriBe Members ',
#  'Mid Waist Floral Print Hipster Panty With Inner Elastic In Lemon Yellow   Cotton₹ 224499FEW LEFT₹199For TriBe Members ',
#  "Women's Violet Solid Stylish Casual Dress₹ 10591799₹999For TriBe Members ",
#  "Women's Black Printed Regular Fit Top₹ 519899₹489For TriBe Members ",
#  "Women's Pink Printed Regular Fit Top₹ 579999FEW LEFT₹539For TriBe Members ",
#  "Women's Grey Cotton Solid Pajama₹ 4991399₹469For TriBe Members "]

# %%
price=[]

for i in soup.find_all(class_="discountedPriceText"):
    price.append(i.text)
    
price
# Out:
# ['₹ 224',
#  '₹ 224',
#  '₹ 189',
#  '₹ 224',
#  '₹ 224',
#  '₹ 224',
#  '₹ 1059',
#  '₹ 519',
#  '₹ 579',
#  '₹ 499']

# %%
images=[]

for i in soup.find_all("img",class_="productImgTag"):
    images.append(i.['img src='])
    
images
# Out:
#   File "C:\Users\DRC44C~1.SAI\AppData\Local\Temp/ipykernel_11800/727920165.py", line 4
#     images.append(i.['img src='])
#                     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df3=pd.DataFrame({'Product':product,'Price':price})
df3
# Out:
#                                              Product   Price
# 0  Mid Waist Striped Hipster Panty In White   Cot...   ₹ 224
# 1  High Waist Hipster Panty With Text Print Waist...   ₹ 224
# 2  Cotton High Waist Striped Hipster Panty₹ 18949...   ₹ 189
# 3  Mid Waist Hipster Panty With Dog Print Back In...   ₹ 224
# 4  Mid Waist Hipster Panty With Text & Graphic Pr...   ₹ 224
# 5  Mid Waist Floral Print Hipster Panty With Inne...   ₹ 224
# 6  Women's Violet Solid Stylish Casual Dress₹ 105...  ₹ 1059
# 7  Women's Black Printed Regular Fit Top₹ 519899₹...   ₹ 519
# 8  Women's Pink Printed Regular Fit Top₹ 579999FE...   ₹ 579
# 9  Women's Grey Cotton Solid Pajama₹ 4991399₹469F...   ₹ 499
